# %% [markdown]
# # Unsteady flow through a cylinder array at an angle ($Re=200$)

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
import numpy as np
import matplotlib.pyplot as plt

import ibmos as ib

# %% [markdown]
# ## Numerical grid and solver initialization

# %%
s1 = ib.stretching(256, 0.033, 0.20, int(0.5/0.033+16), 16, 16, 0.04)
s2 = ib.stretching(128, 0.033, 0.20, int(0.5/0.033+16), 16, 16, 0.04)
x = np.r_[-s2[::-1], s1[1:]]

s = ib.stretching(34, 0.033, 0.20, int(0.5/0.033+16), 16, 16, 0.04)
y = np.r_[-s[::-1], s[1:]]

solver = ib.Solver(x, y, periodic=True, iRe=1/200.0, Co=0.30)

# %%
(len(y)-1)/3
# Out:
# 22.0

# %% [markdown]
# ## Immersed boundaries

# %%
solver.set_solids(ib.shapes.cylinder("cylinder", 0, 0, 0.5, solver.dxmin))

# %%
solver.plot_domain(figsize=(6, 5), xlim=(-1, 4), ylim=(-2, 2));

# %% [markdown]
# ## Boundary conditions

# %%
uBC, vBC = solver.zero_boundary_conditions()

α = 30*np.pi/180
for k in range(2):
    uBC[k][:] = np.cos(α)
    vBC[k][:] = np.sin(α)

sBC = ((np.zeros(solver.solids[0].l), np.zeros(solver.solids[0].l)), )

# %% [markdown]
# ## Initial condition

# %%
u, v, p, *f = solver.reshape(*solver.unpack(solver.zero()))
c, r, ϵ = -4, 0.5, 0.01
u[:,:] = np.cos(α) - ϵ*solver.fluid.u.y[:,np.newaxis]*np.exp(-((solver.fluid.u.x[np.newaxis,:]-c)**2 + solver.fluid.u.y[:,np.newaxis]**2)/r**2)
v[:,:] = np.sin(α) + ϵ*(solver.fluid.v.x[np.newaxis,:]-c)*np.exp(-((solver.fluid.v.x[np.newaxis,:]-c)**2 + solver.fluid.v.y[:,np.newaxis]**2)/r**2)
x0 = solver.pack(u, v, p, f)

# %%
solver.plot_field(x0, xlim=(-4.30, 1), ylim=(-3, 3))

# %% [markdown]
# ## Unsteady simulation

# %%
# %%time 
x, t, infodict = solver.steps(x0, uBC, vBC, sBC, outflowEast=True, 
                              saveEvery=int(0.15/solver.dt), number=int(50/solver.dt), verbose=int(2/solver.dt))
# Out:
#        k            t          x_2       dxdt_2  cylinder_fx  cylinder_fy  Uinf@outlet
#      202  1.99980e+00  2.14511e+02  3.95828e+01  2.79839e+00  2.41977e-01  8.66025e-01
#      404  3.99960e+00  2.05035e+02  7.53916e+01  2.20852e+00  1.85572e+00  8.66025e-01
#      606  5.99940e+00  2.22829e+02  1.00641e+02  3.11937e+00 -2.86879e-02  8.66025e-01
#      808  7.99920e+00  2.04693e+02  9.47278e+01  2.23661e+00  1.48694e+00  8.66025e-01
#     1010  9.99900e+00  2.23030e+02  8.24424e+01  2.84827e+00  1.60550e-01  8.66025e-01
#     1212  1.19988e+01  2.05505e+02  1.18510e+02  2.21354e+00  1.51413e+00  8.66025e-01
#     1414  1.39986e+01  2.22037e+02  9.39263e+01  2.78615e+00  2.44297e-01  8.66025e-01
#     1616  1.59984e+01  2.06252e+02  1.21669e+02  2.21670e+00  1.50679e+00  8.66025e-01
#     1818  1.79982e+01  2.22829e+02  1.00820e+02  2.80561e+00  2.30058e-01  8.66025e-01
#     2020  1.99980e+01  2.06639e+02  1.24716e+02  2.22293e+00  1.49382e+00  8.66025e-01
#     2222  2.19978e+01  2.23426e+02  1.04399e+02  2.81123e+00  2.24193e-01  8.66025e-01
#     2424  2.39976e+01  2.06990e+02  1.28022e+02  2.22361e+00  1.49309e+00  8.66025e-01
#     2626  2.59974e+01  2.23716e+02  1.08162e+02  2.81549e+00  2.22960e-01  8.66025e-01
#     2828  2.79972e+01  2.07229e+02  1.30185e+02  2.22618e+00  1.48680e+00  8.66025e-01
#     3030  2.99970e+01  2.23990e+02  1.10991e+02  2.82026e+00  2.20435e-01  8.66025e-01
#     3232  3.19968e+01  2.07385e+02  1.32097e+02  2.22819e+00  1.48175e+00  8.66025e-01
#     3434  3.39966e+01  2.24170e+02  1.13431e+02  2.82465e+00  2.18657e-01  8.66025e-01
#     3636  3.59964e+01  2.07473e+02  1.33639e+02  2.23030e+00  1.47606e+00  8.66025e-01
#     3838  3.79962e+01  2.24291e+02  1.15506e+02  2.82890e+00  2.17059e-01  8.66025e-01
#     4040  3.99960e+01  2.07498e+02  1.34938e+02  2.23233e+00  1.47029e+00  8.66025e-01
#     4242  4.19958e+01  2.24354e+02  1.17298e+02  2.83296e+00  2.15774e-01  8.66025e-01
#     4444  4.39956e+01  2.07469e+02  1.36013e+02  2.23434e+00  1.46429e+00  8.66025e-01
#     4646  4.59954e+01  2.24360e+02  1.18845e+02  2.83684e+00  2.14768e-01  8.66025e-01
#     4848  4.79952e+01  2.07319e+02  1.36899e+02  2.23631e+00  1.45811e+00  8.66025e-01
#     5050  4.99950e+01  2.24296e+02  1.20075e+02  2.84051e+00  2.14055e-01  8.66025e-01
# CPU times: user 13min 2s, sys: 12.2 s, total: 13min 15s
# Wall time: 3min 19s

# %% [markdown]
# ## Display results

# %% [markdown]
# Display velocity field and pressure at the last time step

# %%
solver.plot_field(x[-1], equal=True, xlim=(-1, 4.3), ylim=(-2, 2));

# %% [markdown]
# Temporal evolution of the force coefficients

# %%
plt.plot(infodict['t'], infodict['cylinder_fx'], label=r'$C_d$')
plt.plot(infodict['t'], infodict['cylinder_fy'], label=r'$C_l$')
plt.ylim(-2, 3)
plt.xlabel('t')
plt.ylabel('Coefficients')
plt.legend();

# %% [markdown]
# Animation

# %%
from IPython.display import HTML
from matplotlib import animation
# %config InlineBackend.figure_format = 'png'

# %%
plt.figure()
fig, ax = plt.subplots(figsize=(9.5, 5))
Ly = (y[-1]-y[0])
quad = ax.pcolormesh(solver.fluid.u.x, 
                     np.r_[solver.fluid.u.y - Ly, solver.fluid.u.y, solver.fluid.u.y + Ly],
                     np.vstack([solver.reshape(*solver.unpack(x[0]))[0],]*3),
                     rasterized=True, shading='gouraud')

for solid in solver.solids:
    plt.plot(solid.ξ, solid.η-Ly)
    plt.plot(solid.ξ, solid.η)
    plt.plot(solid.ξ, solid.η+Ly)
    
ax.axis('equal')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_xlim(-2.8, 10)
ax.set_ylim(-2, 2)
fig.tight_layout()

# %%
def init():
    quad.set_array([])
    return quad,

def animate(i):
    array = np.r_[solver.unpack(x[i])[0].ravel(), solver.unpack(x[i])[0].ravel(),solver.unpack(x[i])[0].ravel()]
    quad.set_array(array)
    return quad,

anim = animation.FuncAnimation(fig, animate, init_func=init, 
                               frames=len(x), interval=15, blit=True)

# %%
# %time HTML(anim.to_html5_video())
# Out:
# CPU times: user 1min 25s, sys: 196 ms, total: 1min 25s
# Wall time: 1min 25s
# <video width="684" height="360" controls autoplay loop>
#   <source type="video/mp4" src="...
